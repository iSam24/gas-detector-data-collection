# %% [markdown]
# Model Architecture
#
# * 2D CNN + GRU for IR camera data
# * 1D CNN for gas data
# * Late stage sensor fusion (concat after encoding)
#
# ```
# IR Frames (20, 32, 24)                  Gas (20, 3)
#         │                                     │
# TimeDistributed                          Conv1D(16, k=3)
#   Conv2D(8, 3×3) → BN → ReLU            BN → ReLU
#   MaxPool(2×2)                           Conv1D(32, k=3)
#   Conv2D(16, 3×3) → BN → ReLU           BN → ReLU
#   GlobalAvgPool2D                        GlobalAvgPool1D
#         │ (20, 16)                            │ (32,)
#       GRU(32)
#         │ (32,)
#         └──────────── Concatenate ───────────┘
#                            │ (64,)
#                      Dense(64) → BN → ReLU → Dropout(0.4)
#                            │
#                       Dense(4) → Softmax
# ```

# %%
# !pip install -q matplotlib seaborn scikit-learn

# %%
import os
import glob
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

print(f"TensorFlow version : {tf.__version__}")
tf.config.list_physical_devices('GPU')
# Out:
# TensorFlow version : 2.19.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load data
# Copy data from the raspberry pi
# scp -r isam@192.168.1.109:/home/isam/dev/MLX90640/data_extraction/dataset C:/Users/SamWh/Programming/gas-detector-data
from google.colab import drive
drive.mount("/content/drive")
DATA_ROOT = '/content/drive/MyDrive/gas-data-v1'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Set seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
CLASS_NAMES = ["aerosol","flame", "normal"]
N_TIMESTEPS  = 20      # 4 Hz × 5 s
IR_H, IR_W   = 32, 24
N_GAS        = 3
N_CLASSES    = len(CLASS_NAMES)

# %% [markdown]
# ## Data Loading & EDA

# %%
def load_dataset(data_root: str, class_names: list) -> tuple:
    """ Loads all .npz files
      Returns:
        ir_avg    : (32,24)          - Average thermal image
        ir_frames : (N, 20, 32, 24)  — full thermal video sequence
        gas       : (N, 20, 3)       — gas sensor timeseries
        labels    : (N,)             — integer class labels
    """
    ir_avg_list, ir_frames_list, gas_list, label_list = [], [], [], []

    for class_idx, class_name in enumerate(class_names):
      class_dir = os.path.join(data_root, class_name)
      files = sorted(glob.glob(os.path.join(class_dir, "*.npz")))

      if len(files) == 0:
        print(f"No files found for class '{class_name}' in '{class_dir}")
        continue

      print(f"[{class_idx}] {class_name:10s} -> {len(files)} samples")

      for fpath in files:
        data = np.load(fpath)
        ir_avg_list.append(data["ir"].astype(np.float32))  # (32, 24)
        ir_frames_list.append(data["ir_frames"].astype(np.float32))  # (20, 32, 24)
        gas_list.append(data["gas"].astype(np.float32))               # (20, 3)
        label_list.append(class_idx)

    ir_avg    = np.stack(ir_avg_list, axis=0)      # (32, 24)
    ir_frames = np.stack(ir_frames_list, axis=0)   # (N, 20, 32, 24)
    gas       = np.stack(gas_list, axis=0)         # (N, 20, 3)
    labels    = np.array(label_list, dtype=np.int32)


    print(f"Dataset loaded:")
    print(f"   ir_avg shape    : {ir_avg.shape}")
    print(f"   ir_frames shape : {ir_frames.shape}")
    print(f"   gas shape       : {gas.shape}")
    print(f"   labels shape    : {labels.shape}")
    print(f"   Class balance   : {np.bincount(labels)}")
    return ir_avg, ir_frames, gas, labels

print("Loading dataset...")
ir_avg, ir_frames, gas, labels = load_dataset(DATA_ROOT, CLASS_NAMES)
# Out:
# Loading dataset...
# [0] aerosol    -> 30 samples
# [1] flame      -> 30 samples
# [2] normal     -> 30 samples
# Dataset loaded:
#    ir_avg shape    : (90, 32, 24)
#    ir_frames shape : (90, 20, 32, 24)
#    gas shape       : (90, 20, 3)
#    labels shape    : (90,)
#    Class balance   : [30 30 30]

# %%
def audit_dataset(ir_frames, gas, labels, class_names):
    """
    Audit every sample for NaN, Inf, and constant channels.
    Returns a boolean mask of CLEAN samples.
    """
    print("═" * 55)
    print("  DATA AUDIT")
    print("═" * 55)
    n = len(labels)
    clean_mask = np.ones(n, dtype=bool)

    for i in range(n):
        ir_bad  = not np.isfinite(ir_frames[i]).all()
        gas_bad = not np.isfinite(gas[i]).all()

        if ir_bad or gas_bad:
            clean_mask[i] = False
            cname = class_names[labels[i]]
            print(f"  ⚠️  Sample {i:3d} [{cname}]: "
                  f"IR {'NaN/Inf' if ir_bad else 'OK':8s} | "
                  f"Gas {'NaN/Inf' if gas_bad else 'OK'}")

    n_bad = (~clean_mask).sum()
    n_clean = clean_mask.sum()
    print(f"\n  Total samples : {n}")
    print(f"  Bad  samples  : {n_bad}")
    print(f"  Clean samples : {n_clean}")

    if n_bad > 0:
        print("\n  Class balance AFTER cleaning:")
        clean_labels = labels[clean_mask]
        for ci, cn in enumerate(class_names):
            count = (clean_labels == ci).sum()
            print(f"    [{ci}] {cn:10s}: {count} samples")

    # Also check for constant channels in gas (std == 0 per channel)
    print("\n  Gas channel std (should be > 0 for all):")
    for ch in range(gas.shape[-1]):
        ch_std = gas[:, :, ch][clean_mask].std()
        flag = "⚠️  CONSTANT" if ch_std < 1e-3 else "✅"
        print(f"    Channel {ch}: std = {ch_std:.4f}  {flag}")

    print("═" * 55)
    return clean_mask


clean_mask = audit_dataset(ir_frames, gas, labels, CLASS_NAMES)

# Apply mask — drop bad samples entirely
ir_frames = ir_frames[clean_mask]
gas       = gas[clean_mask]
labels    = labels[clean_mask]

print(f"\nDataset after cleaning: {len(labels)} samples")
# Out:
# ═══════════════════════════════════════════════════════
#   DATA AUDIT
# ═══════════════════════════════════════════════════════
#   ⚠️  Sample  57 [flame]: IR NaN/Inf  | Gas OK
#
#   Total samples : 90
#   Bad  samples  : 1
#   Clean samples : 89
#
#   Class balance AFTER cleaning:
#     [0] aerosol   : 30 samples
#     [1] flame     : 29 samples
#     [2] normal    : 30 samples
#
#   Gas channel std (should be > 0 for all):
#     Channel 0: std = 14397.7646  ✅
#     Channel 1: std = 14473.9258  ✅
#     Channel 2: std = 31792.9277  ✅
# ═══════════════════════════════════════════════════════
#
# Dataset after cleaning: 89 samples

# %% [markdown]
# Exploratory Visualisation

# %%
fig, axes = plt.subplots(2, N_CLASSES, figsize=(14, 6))
fig.suptitle("Representative IR Frame (avg) per Class", fontsize=13, fontweight="bold")

for col, class_name in enumerate(CLASS_NAMES):
    idx = np.where(labels == col)[0][0]

    # Average IR frame across time
    avg_frame = ir_avg[idx]
    axes[0, col].imshow(avg_frame, cmap="inferno", aspect="auto")
    axes[0, col].set_title(class_name, fontweight="bold")
    axes[0, col].axis("off")

    # Gas timeseries
    axes[1, col].plot(gas[idx], label=["MQ-2", "MQ-7", "MQ-135"])
    axes[1, col].set_xlabel("Timestep (0.25s each)")
    if col == 0:
        axes[1, col].set_ylabel("Gas reading")
        axes[1, col].legend(fontsize=8)

plt.tight_layout()
plt.savefig("eda_overview.png", dpi=150, bbox_inches="tight")
plt.show()
print("EDA plot saved.")
# Out:
# EDA plot saved.

# %% [markdown]
# ## IR-relative features
#
# Input IR-relative features to the model rather than absolute temperatures. The difference between pixels matters more than the absolute value. Reduces the impact of ambient temperature changes.

# %%
def make_ir_relative(ir_frames):
    """
    Subtract per-frame spatial mean to remove ambient temperature.
    ir_frames: (N, 20, 32, 24) for batch  or  (20, 32, 24) for single sample
    """
    if ir_frames.ndim == 4:
        # batch: mean over H and W axes
        return ir_frames - ir_frames.mean(axis=(2, 3), keepdims=True)  # (N,20,1,1)
    elif ir_frames.ndim == 3:
        # single sample: mean over H and W axes
        return ir_frames - ir_frames.mean(axis=(1, 2), keepdims=True)  # (20,1,1)

# %% [markdown]
# Preprocessing & Normalisaiton
#
# # Normalisation strategy:
# **IR frames**: per-pixel z-score using training set statistics.
# Thermal cameras have a stable absolute temperature range → z-score preserves
# the relative temperature gradient that distinguishes classes.
#
# **Gas**: per-channel z-score. Gas sensors have very different absolute ranges
# across the 3 channels, normalising each independently prevents one channel
# from dominating the loss gradient.

# %%
def compute_normalization_stats(ir_frames_train, gas_train):
    """Compute mean/std on training split only."""
    # IR: mean/std over (N, time, H, W) → result shape (1, 1, H, W) for broadcasting
    ir_mean = ir_frames_train.mean(axis=(0, 1), keepdims=True)   # (1, 1, 32, 24)
    ir_std  = ir_frames_train.std(axis=(0, 1), keepdims=True) + 1e-6

    # Gas: mean/std over (N, time) per channel → (1, 1, 3)
    gas_mean = gas_train.mean(axis=(0, 1), keepdims=True)         # (1, 1, 3)
    gas_std  = gas_train.std(axis=(0, 1), keepdims=True) + 1e-6

    return ir_mean, ir_std, gas_mean, gas_std


def normalize(ir_frames, gas, ir_mean, ir_std, gas_mean, gas_std):
    """Apply z-score normalisation using precomputed statistics."""
    ir_norm  = (ir_frames - ir_mean) / ir_std
    gas_norm = (gas - gas_mean) / gas_std
    return ir_norm, gas_norm

# %% [markdown]
# # Data Augmentation
#
# With only 120 samples, data augmentatiom is required to prevent the model learning the training data and over fitting.
#
# ### Augmentation strategy:
# 1. Gaussian noise for IR + gas: Simulates sensor noise, most impactful regulariser
# 2. Horizontal flip for IR frames: Thermal scene is horizontally symmetric
# 3. Temporal jitter (±1 frame shift) for IR + gas: Accounts for non-exact alignment at capture start
# 4. Amplitude scale (0.9-1.1x) for gas: Gas sensors have gain drift between recordings
# 5. Random frame dropout (set 1-2 frames to mean) for IR: Teaches model not to rely on single frames

# %%
def augment_sample(ir_seq, gas_seq, rng: np.random.Generator):
    """
    Augment a single (ir_seq, gas_seq) pair.
    ir_seq  : (20, 32, 24)
    gas_seq : (20, 3)
    Returns augmented versions of the same shapes.
    """
    ir  = ir_seq.copy()
    gas = gas_seq.copy()

    # 1. Gaussian noise
    if rng.random() > 0.3:
        ir  += rng.normal(0, 0.05, ir.shape).astype(np.float32)
    if rng.random() > 0.3:
        gas += rng.normal(0, 0.03, gas.shape).astype(np.float32)

    # 2. Horizontal flip of IR frames
    if rng.random() > 0.5:
        ir = ir[:, :, ::-1]   # flip width axis

    # 3. Temporal jitter: shift by ±1 timestep with zero-padding
    if rng.random() > 0.5:
        shift = rng.integers(-1, 2)  # -1, 0, or +1
        if shift != 0:
            ir  = np.roll(ir,  shift, axis=0)
            gas = np.roll(gas, shift, axis=0)
            if shift > 0:
                ir[:shift]  = 0;  gas[:shift]  = 0
            else:
                ir[shift:]  = 0;  gas[shift:]  = 0

    # 4. Gas amplitude scale
    if rng.random() > 0.4:
        scale = rng.uniform(0.9, 1.1)
        gas  *= scale

    # 5. Random IR frame dropout (replace 1-2 frames with channel mean)
    if rng.random() > 0.5:
        n_drop = rng.integers(1, 3)
        drop_idx = rng.choice(20, n_drop, replace=False)
        for d in drop_idx:
            ir[d] = ir.mean(axis=0)

    return ir.astype(np.float32), gas.astype(np.float32)

def augment_batch(ir_batch, gas_batch, n_aug_per_sample=3, seed=42):
    """
    Augment every sample in a batch n_aug_per_sample times.
    Returns the original + augmented data concatenated.
    """
    rng = np.random.default_rng(seed)
    aug_ir, aug_gas = [ir_batch], [gas_batch]

    for _ in range(n_aug_per_sample):
        new_ir  = np.zeros_like(ir_batch)
        new_gas = np.zeros_like(gas_batch)
        for i in range(len(ir_batch)):
            new_ir[i], new_gas[i] = augment_sample(ir_batch[i], gas_batch[i], rng)
        aug_ir.append(new_ir)
        aug_gas.append(new_gas)

    return np.concatenate(aug_ir), np.concatenate(aug_gas)

# %% [markdown]
# # Model Architecture
#
# The model has two input branches that are fused before the classification head. The model is kept small (~12K parameters) to avoid overfitting

# %%
def build_model(n_timesteps=20,ir_h=32, ir_w=24,n_gas=3,
                n_classes=3,l2_lambda=1e-4, tflite_export=False) -> tf.keras.Model:

    # This creates an L2 regulariser, which adds a penalty to the loss based on
    # the size of the model’s weights. helps prevent over fitting
    reg = tf.keras.regularizers.l2(l2_lambda)

    # ------------------------------ IR Branch ------------------------------
    # Input dimensions: (20, 32, 24)
    ir_input = tf.keras.Input(shape=(n_timesteps, ir_h, ir_w), name="ir_frames")

    # Add a channel dimension (B,20,32,24,1)
    x = tf.keras.layers.Reshape((n_timesteps, ir_h, ir_w, 1))(ir_input)

    # LAYER 1
    # TimeDistributed CNN: same CNN applied to each of the 20 frames
    # num of filters = 8
    # kernel size = 3x3
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.Conv2D(8,
                                        (3, 3), padding="same",
                                        kernel_regularizer=reg), name="td_conv1")(x)

    # Batch Normalization (keeps intermediate features centered and scaled)
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.BatchNormalization())(x)

    # Introduce no linearity and prevent vanishing gradients
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.ReLU())(x)

    # Max Pooling - downsampling
    # Look at every 2x2 block and keep the highest activation value
    # [1  5]
    # [2  3]   →   5
    # (B, 20, 16, 12, 8)
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.MaxPool2D((2, 2)),name="td_pool1")(x)

    # LAYER 2
    # 2nd 2D CNN
    # num of filters = 16
    # kernel size = 3x3
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.Conv2D(16,
                                        (3, 3), padding="same",
                                        kernel_regularizer=reg), name="td_conv2")(x)
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.BatchNormalization())(x)
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.ReLU())(x)

    # GlobalAveragePooling (B, 20, 16)
    # For each channel (output of a filter) calculate average activation over the whole image
    # Compresses channel activation into a 16 dimension summary vector
    x = tf.keras.layers.TimeDistributed(tf.keras.layers.GlobalAveragePooling2D(),name="td_gap")(x)

    # Gated Recurrent Unit (GRU) - a type of RNN that learns patterns over time
    # GRUs have gates that control information flow:
    # Update gate → how much new info to add
    # Reset gate → how much past info to forget

    # GRU for temporal modelling of IR feature sequence (B, 16)
    if tflite_export:
        # Explicit RNN+GRUCell unrolls cleanly to static ops for TFLite
        gru_cell = tf.keras.layers.GRUCell(
            16,
            kernel_regularizer=reg,
            name="ir_gru_cell"
        )
        x = tf.keras.layers.RNN(
            gru_cell,
            return_sequences=False,
            unroll=True,           # forces fully static graph
            name="ir_gru"
        )(x)
    else:
        # Standard GRU — uses CuDNN on GPU during training
        x = tf.keras.layers.GRU(
            16,
            return_sequences=False,
            kernel_regularizer=reg,
            name="ir_gru"
        )(x)


    # Randomly zero 30% of inputs - prevents overfitting in training and improves generalisation
    x = tf.keras.layers.Dropout(0.3)(x)

    ir_features = x  # (B, 32)


    # ------------------------------ Gas Branch ------------------------------
    # Input: (batch, 20, 3)
    gas_input = tf.keras.Input(shape=(n_timesteps, n_gas), name="gas")
    g = tf.keras.layers.Conv1D(16, 3, padding="same", kernel_regularizer=reg, name="gas_conv1")(gas_input)
    g = tf.keras.layers.BatchNormalization()(g)
    g = tf.keras.layers.ReLU()(g)
    g = tf.keras.layers.Conv1D(32, 3, padding="same", kernel_regularizer=reg, name="gas_conv2")(g)
    g = tf.keras.layers.BatchNormalization()(g)
    g = tf.keras.layers.ReLU()(g)
    g = tf.keras.layers.GlobalAveragePooling1D(name="gas_gap")(g)   # (B, 32)
    g = tf.keras.layers.Dropout(0.3)(g)
    gas_features = g  # (B, 32)

    # ------------------------------ Fusion Head ------------------------------
    fused = tf.keras.layers.Concatenate(name="fusion")([ir_features, gas_features])  # (B, 64)
    fused = tf.keras.layers.Dense(64, kernel_regularizer=reg, name="fc1")(fused)
    fused = tf.keras.layers.BatchNormalization()(fused)
    fused = tf.keras.layers.ReLU()(fused)
    fused = tf.keras.layers.Dropout(0.4)(fused)
    output = tf.keras.layers.Dense(n_classes, activation="softmax", name="output")(fused)

    model = tf.keras.Model(inputs={"ir_frames": ir_input, "gas": gas_input},
                           outputs=output, name="SensorFusionClassifier")
    return model

# Print summary
model_preview = build_model()
model_preview.summary()
print(f"\nTotal parameters: {model_preview.count_params():,}")

# tf.keras.utils.plot_model(model_preview, show_shapes=True, dpi=100)
# Out:
# Model: "SensorFusionClassifier"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ir_frames           │ (None, 20, 32,    │          0 │ -                 │
# │ (InputLayer)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 20, 32,    │          0 │ ir_frames[0][0]   │
# │                     │ 24, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ td_conv1            │ (None, 20, 32,    │         80 │ reshape_2[0][0]   │
# │ (TimeDistributed)   │ 24, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_8  │ (None, 20, 32,    │         32 │ td_conv1[0][0]    │
# │ (TimeDistributed)   │ 24, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gas (InputLayer)    │ (None, 20, 3)     │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_9  │ (None, 20, 32,    │          0 │ time_distributed… │
# │ (TimeDistributed)   │ 24, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gas_conv1 (Conv1D)  │ (None, 20, 16)    │        160 │ gas[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ td_pool1            │ (None, 20, 16,    │          0 │ time_distributed… │
# │ (TimeDistributed)   │ 12, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 16)    │         64 │ gas_conv1[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ td_conv2            │ (None, 20, 16,    │      1,168 │ td_pool1[0][0]    │
# │ (TimeDistributed)   │ 12, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 20, 16)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_10 │ (None, 20, 16,    │         64 │ td_conv2[0][0]    │
# │ (TimeDistributed)   │ 12, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gas_conv2 (Conv1D)  │ (None, 20, 32)    │      1,568 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_11 │ (None, 20, 16,    │          0 │ time_distributed… │
# │ (TimeDistributed)   │ 12, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 32)    │        128 │ gas_conv2[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ td_gap              │ (None, 20, 16)    │          0 │ time_distributed… │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 20, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ir_gru (GRU)        │ (None, 16)        │      1,632 │ td_gap[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gas_gap             │ (None, 32)        │          0 │ re_lu_10[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16)        │          0 │ ir_gru[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32)        │          0 │ gas_gap[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion              │ (None, 48)        │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1 (Dense)         │ (None, 64)        │      3,136 │ fusion[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ fc1[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 3)         │        195 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,483 (33.14 KB)
#  Trainable params: 8,211 (32.07 KB)
#  Non-trainable params: 272 (1.06 KB)
# Total parameters: 8,483

# %% [markdown]
# # Training with Stratified 5-Fold Cross Validation
# ### Why K-Fold instead of a single train/val split?
# With 30 samples per class, a single 80/20 split gives only ~6 val samples per class which is far too few to estimate generalisation reliably. 5-fold CV trains 5 models and averages, giving a robust estimate. T5 Fold CV helps find hyperparameters that we can use when training the single model eg number of epochs.

# %%
# Hyperparameters
N_FOLDS          = 5      # Number of folds
N_AUG_PER_SAMPLE = 3      # training set becomes 4× the original size per fold
BATCH_SIZE       = 16
EPOCHS           = 120
LR               = 3e-4   # Learning rate
L2_LAMBDA        = 1e-4   # strength of L2 regularisation. How strongly you penalise large weights in your model.

CHECKPOINT_DIR = "/content/checkpoints"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# %%
def make_callbacks(fold_id: int, checkpoint_dir: str) -> list:
    """Callbacks: checkpoint best model + reduce LR on plateau + early stopping."""
    ckpt_path = os.path.join(checkpoint_dir, f"fold_{fold_id}_best.keras")
    return [
        tf.keras.callbacks.ModelCheckpoint(
            filepath=ckpt_path,
            monitor="val_accuracy",
            save_best_only=True,
            verbose=0
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=12,
            min_lr=1e-6,
            verbose=1
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor="val_accuracy",
            patience=25,
            restore_best_weights=True,
            verbose=1
        )
    ]

# %%
# Train 5 fold cross validation

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)

fold_histories  = []
fold_val_accs   = []
fold_val_losses = []

print(f"Starting {N_FOLDS}-Fold Cross Validation")

print(f"Augmentation: {N_AUG_PER_SAMPLE}× per sample "
      f"~{int(len(labels) * 0.8) * (N_AUG_PER_SAMPLE + 1)} training samples per fold\n")

for fold_idx, (train_idx, val_idx) in enumerate(skf.split(ir_frames, labels)):
    print(f"{'═'*60}")
    print(f"FOLD {fold_idx + 1} / {N_FOLDS}")
    print(f"Train: {len(train_idx)} samples | Val: {len(val_idx)} samples")
    print(f"{'═'*60}")

    # Split
    ir_train_raw  = ir_frames[train_idx]
    gas_train_raw = gas[train_idx]
    y_train_raw   = labels[train_idx]

    ir_val_raw    = ir_frames[val_idx]
    gas_val_raw   = gas[val_idx]
    y_val         = labels[val_idx]

    # Make relative
    ir_train_rel = make_ir_relative(ir_train_raw)  # (N, 20, 32, 24)
    ir_val_rel   = make_ir_relative(ir_val_raw)

    # Normalise (fit on train only)
    ir_mean, ir_std, gas_mean, gas_std = compute_normalization_stats(
        ir_train_rel, gas_train_raw   # <-- relative IR, not raw
    )

    ir_train_norm, gas_train_norm = normalize(
        ir_train_rel, gas_train_raw, ir_mean, ir_std, gas_mean, gas_std
    )

    ir_val_norm, gas_val_norm = normalize(
        ir_val_rel, gas_val_raw, ir_mean, ir_std, gas_mean, gas_std
    )

    # Augment training data
    ir_train_aug, gas_train_aug = augment_batch(
        ir_train_norm, gas_train_norm,
        n_aug_per_sample=N_AUG_PER_SAMPLE,
        seed=SEED + fold_idx
    )
    y_train_aug = np.tile(y_train_raw, N_AUG_PER_SAMPLE + 1)

    # Shuffle augmented training set
    perm = np.random.permutation(len(y_train_aug))
    ir_train_aug  = ir_train_aug[perm]
    gas_train_aug = gas_train_aug[perm]
    y_train_aug   = y_train_aug[perm]

    print(f" Augmented training size: {len(y_train_aug)}")

    # Build & compile fresh model
    model = build_model(l2_lambda=L2_LAMBDA)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    # Train
    history = model.fit(
        x={"ir_frames": ir_train_aug, "gas": gas_train_aug},
        y=y_train_aug,
        validation_data=(
            {"ir_frames": ir_val_norm, "gas": gas_val_norm},
            y_val
        ),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=make_callbacks(fold_idx, CHECKPOINT_DIR),
        verbose=1
    )

    fold_histories.append(history.history)
    best_val_acc  = max(history.history["val_accuracy"])
    best_val_loss = min(history.history["val_loss"])
    fold_val_accs.append(best_val_acc)
    fold_val_losses.append(best_val_loss)
    print(f"Fold {fold_idx+1} best val accuracy: {best_val_acc:.4f}")
    print(f"Fold {fold_idx+1} best val loss: {best_val_loss:.4f}")
# Out:
# Starting 5-Fold Cross Validation
# Augmentation: 3× per sample ~284 training samples per fold
#
# ════════════════════════════════════════════════════════════
# FOLD 1 / 5
# Train: 71 samples | Val: 18 samples
# ════════════════════════════════════════════════════════════
#  Augmented training size: 284
# Epoch 1/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 26s 191ms/step - accuracy: 0.4894 - loss: 1.0731 - val_accuracy: 0.5556 - val_loss: 1.0650 - learning_rate: 3.0000e-04
# Epoch 2/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5493 - loss: 0.9268 - val_accuracy: 0.9444 - val_loss: 0.9788 - learning_rate: 3.0000e-04
# Epoch 3/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6831 - loss: 0.6962 - val_accuracy: 1.0000 - val_loss: 0.8921 - learning_rate: 3.0000e-04
# Epoch 4/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7782 - loss: 0.5750 - val_accuracy: 1.0000 - val_loss: 0.8039 - learning_rate: 3.0000e-04
# Epoch 5/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8239 - loss: 0.4960 - val_accuracy: 1.0000 - val_loss: 0.7137 - learning_rate: 3.0000e-04
# Epoch 6/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8521 - loss: 0.4372 - val_accuracy: 1.0000 - val_loss: 0.6151 - learning_rate: 3.0000e-04
# Epoch 7/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8768 - loss: 0.3794 - val_accuracy: 1.0000 - val_loss: 0.5255 - learning_rate: 3.0000e-04
# Epoch 8/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9120 - loss: 0.3465 - val_accuracy: 1.0000 - val_loss: 0.4384 - learning_rate: 3.0000e-04
# Epoch 9/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9683 - loss: 0.2666 - val_accuracy: 1.0000 - val_loss: 0.3612 - learning_rate: 3.0000e-04
# Epoch 10/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9401 - loss: 0.2500 - val_accuracy: 1.0000 - val_loss: 0.2977 - learning_rate: 3.0000e-04
# Epoch 11/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9754 - loss: 0.2031 - val_accuracy: 1.0000 - val_loss: 0.2472 - learning_rate: 3.0000e-04
# Epoch 12/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9613 - loss: 0.2012 - val_accuracy: 1.0000 - val_loss: 0.2015 - learning_rate: 3.0000e-04
# Epoch 13/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9683 - loss: 0.1828 - val_accuracy: 1.0000 - val_loss: 0.1631 - learning_rate: 3.0000e-04
# Epoch 14/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9718 - loss: 0.1784 - val_accuracy: 1.0000 - val_loss: 0.1330 - learning_rate: 3.0000e-04
# Epoch 15/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9789 - loss: 0.1712 - val_accuracy: 1.0000 - val_loss: 0.1082 - learning_rate: 3.0000e-04
# Epoch 16/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9824 - loss: 0.1301 - val_accuracy: 1.0000 - val_loss: 0.0899 - learning_rate: 3.0000e-04
# Epoch 17/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9824 - loss: 0.1199 - val_accuracy: 1.0000 - val_loss: 0.0759 - learning_rate: 3.0000e-04
# Epoch 18/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9859 - loss: 0.1315 - val_accuracy: 1.0000 - val_loss: 0.0656 - learning_rate: 3.0000e-04
# Epoch 19/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9930 - loss: 0.1100 - val_accuracy: 1.0000 - val_loss: 0.0562 - learning_rate: 3.0000e-04
# Epoch 20/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9930 - loss: 0.1091 - val_accuracy: 1.0000 - val_loss: 0.0484 - learning_rate: 3.0000e-04
# Epoch 21/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9930 - loss: 0.0849 - val_accuracy: 1.0000 - val_loss: 0.0429 - learning_rate: 3.0000e-04
# Epoch 22/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9894 - loss: 0.1014 - val_accuracy: 1.0000 - val_loss: 0.0379 - learning_rate: 3.0000e-04
# Epoch 23/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9965 - loss: 0.0862 - val_accuracy: 1.0000 - val_loss: 0.0342 - learning_rate: 3.0000e-04
# Epoch 24/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9859 - loss: 0.0967 - val_accuracy: 1.0000 - val_loss: 0.0320 - learning_rate: 3.0000e-04
# Epoch 25/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0838 - val_accuracy: 1.0000 - val_loss: 0.0295 - learning_rate: 3.0000e-04
# Epoch 26/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9965 - loss: 0.0684 - val_accuracy: 1.0000 - val_loss: 0.0281 - learning_rate: 3.0000e-04
# Epoch 27/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9930 - loss: 0.0789 - val_accuracy: 1.0000 - val_loss: 0.0265 - learning_rate: 3.0000e-04
# Epoch 28/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0602 - val_accuracy: 1.0000 - val_loss: 0.0252 - learning_rate: 3.0000e-04
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Fold 1 best val accuracy: 1.0000
# Fold 1 best val loss: 0.0252
# ════════════════════════════════════════════════════════════
# FOLD 2 / 5
# Train: 71 samples | Val: 18 samples
# ════════════════════════════════════════════════════════════
#  Augmented training size: 284
# Epoch 1/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 187ms/step - accuracy: 0.3239 - loss: 1.5180 - val_accuracy: 0.3333 - val_loss: 1.1138 - learning_rate: 3.0000e-04
# Epoch 2/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.5106 - loss: 1.1061 - val_accuracy: 0.9444 - val_loss: 1.0342 - learning_rate: 3.0000e-04
# Epoch 3/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6655 - loss: 0.8426 - val_accuracy: 0.9444 - val_loss: 0.9424 - learning_rate: 3.0000e-04
# Epoch 4/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8063 - loss: 0.6560 - val_accuracy: 0.9444 - val_loss: 0.8414 - learning_rate: 3.0000e-04
# Epoch 5/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8099 - loss: 0.5609 - val_accuracy: 0.9444 - val_loss: 0.7347 - learning_rate: 3.0000e-04
# Epoch 6/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8627 - loss: 0.4342 - val_accuracy: 0.9444 - val_loss: 0.6316 - learning_rate: 3.0000e-04
# Epoch 7/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8662 - loss: 0.3999 - val_accuracy: 0.9444 - val_loss: 0.5396 - learning_rate: 3.0000e-04
# Epoch 8/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8944 - loss: 0.3652 - val_accuracy: 0.9444 - val_loss: 0.4503 - learning_rate: 3.0000e-04
# Epoch 9/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9366 - loss: 0.2918 - val_accuracy: 1.0000 - val_loss: 0.3706 - learning_rate: 3.0000e-04
# Epoch 10/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9261 - loss: 0.2767 - val_accuracy: 1.0000 - val_loss: 0.3077 - learning_rate: 3.0000e-04
# Epoch 11/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9331 - loss: 0.2555 - val_accuracy: 1.0000 - val_loss: 0.2541 - learning_rate: 3.0000e-04
# Epoch 12/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9366 - loss: 0.2334 - val_accuracy: 1.0000 - val_loss: 0.2047 - learning_rate: 3.0000e-04
# Epoch 13/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9507 - loss: 0.2012 - val_accuracy: 1.0000 - val_loss: 0.1696 - learning_rate: 3.0000e-04
# Epoch 14/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9472 - loss: 0.2144 - val_accuracy: 1.0000 - val_loss: 0.1420 - learning_rate: 3.0000e-04
# Epoch 15/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9401 - loss: 0.1945 - val_accuracy: 1.0000 - val_loss: 0.1198 - learning_rate: 3.0000e-04
# Epoch 16/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9577 - loss: 0.1547 - val_accuracy: 1.0000 - val_loss: 0.1084 - learning_rate: 3.0000e-04
# Epoch 17/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9683 - loss: 0.1747 - val_accuracy: 1.0000 - val_loss: 0.1001 - learning_rate: 3.0000e-04
# Epoch 18/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9683 - loss: 0.1457 - val_accuracy: 1.0000 - val_loss: 0.0926 - learning_rate: 3.0000e-04
# Epoch 19/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9613 - loss: 0.1457 - val_accuracy: 1.0000 - val_loss: 0.0852 - learning_rate: 3.0000e-04
# Epoch 20/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9754 - loss: 0.1465 - val_accuracy: 0.9444 - val_loss: 0.0840 - learning_rate: 3.0000e-04
# Epoch 21/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9824 - loss: 0.1230 - val_accuracy: 0.9444 - val_loss: 0.0846 - learning_rate: 3.0000e-04
# Epoch 22/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9683 - loss: 0.1349 - val_accuracy: 0.9444 - val_loss: 0.0741 - learning_rate: 3.0000e-04
# Epoch 23/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9789 - loss: 0.1062 - val_accuracy: 1.0000 - val_loss: 0.0671 - learning_rate: 3.0000e-04
# Epoch 24/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9824 - loss: 0.1115 - val_accuracy: 1.0000 - val_loss: 0.0682 - learning_rate: 3.0000e-04
# Epoch 25/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9789 - loss: 0.1052 - val_accuracy: 1.0000 - val_loss: 0.0662 - learning_rate: 3.0000e-04
# Epoch 26/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9789 - loss: 0.1107 - val_accuracy: 1.0000 - val_loss: 0.0559 - learning_rate: 3.0000e-04
# Epoch 27/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9859 - loss: 0.0925 - val_accuracy: 1.0000 - val_loss: 0.0537 - learning_rate: 3.0000e-04
# Epoch 28/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9754 - loss: 0.1004 - val_accuracy: 0.9444 - val_loss: 0.0717 - learning_rate: 3.0000e-04
# Epoch 29/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9789 - loss: 0.1094 - val_accuracy: 1.0000 - val_loss: 0.0598 - learning_rate: 3.0000e-04
# Epoch 30/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9789 - loss: 0.1083 - val_accuracy: 1.0000 - val_loss: 0.0543 - learning_rate: 3.0000e-04
# Epoch 31/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9824 - loss: 0.0833 - val_accuracy: 1.0000 - val_loss: 0.0502 - learning_rate: 3.0000e-04
# Epoch 32/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9754 - loss: 0.0998 - val_accuracy: 1.0000 - val_loss: 0.0571 - learning_rate: 3.0000e-04
# Epoch 33/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9965 - loss: 0.0727 - val_accuracy: 1.0000 - val_loss: 0.0541 - learning_rate: 3.0000e-04
# Epoch 34/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9754 - loss: 0.0949 - val_accuracy: 1.0000 - val_loss: 0.0430 - learning_rate: 3.0000e-04
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Fold 2 best val accuracy: 1.0000
# Fold 2 best val loss: 0.0430
# ════════════════════════════════════════════════════════════
# FOLD 3 / 5
# Train: 71 samples | Val: 18 samples
# ════════════════════════════════════════════════════════════
#  Augmented training size: 284
# Epoch 1/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 183ms/step - accuracy: 0.3345 - loss: 1.4376 - val_accuracy: 0.3333 - val_loss: 1.1094 - learning_rate: 3.0000e-04
# Epoch 2/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.4859 - loss: 1.1135 - val_accuracy: 0.7778 - val_loss: 0.9972 - learning_rate: 3.0000e-04
# Epoch 3/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.5739 - loss: 0.9102 - val_accuracy: 1.0000 - val_loss: 0.8938 - learning_rate: 3.0000e-04
# Epoch 4/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6479 - loss: 0.7361 - val_accuracy: 1.0000 - val_loss: 0.7962 - learning_rate: 3.0000e-04
# Epoch 5/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7782 - loss: 0.5294 - val_accuracy: 1.0000 - val_loss: 0.6956 - learning_rate: 3.0000e-04
# Epoch 6/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8486 - loss: 0.4720 - val_accuracy: 1.0000 - val_loss: 0.5997 - learning_rate: 3.0000e-04
# Epoch 7/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8662 - loss: 0.4183 - val_accuracy: 1.0000 - val_loss: 0.5056 - learning_rate: 3.0000e-04
# Epoch 8/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9049 - loss: 0.3531 - val_accuracy: 1.0000 - val_loss: 0.4223 - learning_rate: 3.0000e-04
# Epoch 9/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9331 - loss: 0.3065 - val_accuracy: 1.0000 - val_loss: 0.3483 - learning_rate: 3.0000e-04
# Epoch 10/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9225 - loss: 0.2932 - val_accuracy: 1.0000 - val_loss: 0.2862 - learning_rate: 3.0000e-04
# Epoch 11/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9472 - loss: 0.2396 - val_accuracy: 1.0000 - val_loss: 0.2347 - learning_rate: 3.0000e-04
# Epoch 12/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9437 - loss: 0.2201 - val_accuracy: 1.0000 - val_loss: 0.1896 - learning_rate: 3.0000e-04
# Epoch 13/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9331 - loss: 0.2432 - val_accuracy: 1.0000 - val_loss: 0.1556 - learning_rate: 3.0000e-04
# Epoch 14/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9683 - loss: 0.1912 - val_accuracy: 1.0000 - val_loss: 0.1282 - learning_rate: 3.0000e-04
# Epoch 15/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9859 - loss: 0.1691 - val_accuracy: 1.0000 - val_loss: 0.1067 - learning_rate: 3.0000e-04
# Epoch 16/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9613 - loss: 0.1862 - val_accuracy: 1.0000 - val_loss: 0.0894 - learning_rate: 3.0000e-04
# Epoch 17/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9824 - loss: 0.1491 - val_accuracy: 1.0000 - val_loss: 0.0745 - learning_rate: 3.0000e-04
# Epoch 18/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9824 - loss: 0.1285 - val_accuracy: 1.0000 - val_loss: 0.0632 - learning_rate: 3.0000e-04
# Epoch 19/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9718 - loss: 0.1441 - val_accuracy: 1.0000 - val_loss: 0.0541 - learning_rate: 3.0000e-04
# Epoch 20/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9859 - loss: 0.1035 - val_accuracy: 1.0000 - val_loss: 0.0473 - learning_rate: 3.0000e-04
# Epoch 21/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9754 - loss: 0.1212 - val_accuracy: 1.0000 - val_loss: 0.0418 - learning_rate: 3.0000e-04
# Epoch 22/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9824 - loss: 0.1144 - val_accuracy: 1.0000 - val_loss: 0.0376 - learning_rate: 3.0000e-04
# Epoch 23/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9930 - loss: 0.0978 - val_accuracy: 1.0000 - val_loss: 0.0337 - learning_rate: 3.0000e-04
# Epoch 24/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9930 - loss: 0.0938 - val_accuracy: 1.0000 - val_loss: 0.0308 - learning_rate: 3.0000e-04
# Epoch 25/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9894 - loss: 0.1051 - val_accuracy: 1.0000 - val_loss: 0.0292 - learning_rate: 3.0000e-04
# Epoch 26/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9930 - loss: 0.0840 - val_accuracy: 1.0000 - val_loss: 0.0274 - learning_rate: 3.0000e-04
# Epoch 27/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9859 - loss: 0.0869 - val_accuracy: 1.0000 - val_loss: 0.0254 - learning_rate: 3.0000e-04
# Epoch 28/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9930 - loss: 0.0865 - val_accuracy: 1.0000 - val_loss: 0.0238 - learning_rate: 3.0000e-04
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Fold 3 best val accuracy: 1.0000
# Fold 3 best val loss: 0.0238
# ════════════════════════════════════════════════════════════
# FOLD 4 / 5
# Train: 71 samples | Val: 18 samples
# ════════════════════════════════════════════════════════════
#  Augmented training size: 284
# Epoch 1/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 20s 279ms/step - accuracy: 0.3204 - loss: 1.8121 - val_accuracy: 0.3333 - val_loss: 1.1247 - learning_rate: 3.0000e-04
# Epoch 2/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4437 - loss: 1.3112 - val_accuracy: 0.7778 - val_loss: 1.0159 - learning_rate: 3.0000e-04
# Epoch 3/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6092 - loss: 0.9986 - val_accuracy: 0.8889 - val_loss: 0.9092 - learning_rate: 3.0000e-04
# Epoch 4/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7289 - loss: 0.7586 - val_accuracy: 0.9444 - val_loss: 0.8010 - learning_rate: 3.0000e-04
# Epoch 5/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.7711 - loss: 0.6451 - val_accuracy: 1.0000 - val_loss: 0.6935 - learning_rate: 3.0000e-04
# Epoch 6/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8697 - loss: 0.4841 - val_accuracy: 1.0000 - val_loss: 0.5890 - learning_rate: 3.0000e-04
# Epoch 7/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9014 - loss: 0.4244 - val_accuracy: 1.0000 - val_loss: 0.4953 - learning_rate: 3.0000e-04
# Epoch 8/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8944 - loss: 0.3497 - val_accuracy: 1.0000 - val_loss: 0.4153 - learning_rate: 3.0000e-04
# Epoch 9/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9225 - loss: 0.3688 - val_accuracy: 1.0000 - val_loss: 0.3416 - learning_rate: 3.0000e-04
# Epoch 10/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9120 - loss: 0.3228 - val_accuracy: 1.0000 - val_loss: 0.2792 - learning_rate: 3.0000e-04
# Epoch 11/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9155 - loss: 0.2779 - val_accuracy: 1.0000 - val_loss: 0.2295 - learning_rate: 3.0000e-04
# Epoch 12/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9366 - loss: 0.2549 - val_accuracy: 1.0000 - val_loss: 0.1872 - learning_rate: 3.0000e-04
# Epoch 13/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9577 - loss: 0.2103 - val_accuracy: 1.0000 - val_loss: 0.1529 - learning_rate: 3.0000e-04
# Epoch 14/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9648 - loss: 0.1813 - val_accuracy: 1.0000 - val_loss: 0.1273 - learning_rate: 3.0000e-04
# Epoch 15/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9472 - loss: 0.1912 - val_accuracy: 1.0000 - val_loss: 0.1080 - learning_rate: 3.0000e-04
# Epoch 16/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9577 - loss: 0.1823 - val_accuracy: 1.0000 - val_loss: 0.0898 - learning_rate: 3.0000e-04
# Epoch 17/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9718 - loss: 0.1491 - val_accuracy: 1.0000 - val_loss: 0.0779 - learning_rate: 3.0000e-04
# Epoch 18/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9683 - loss: 0.1609 - val_accuracy: 1.0000 - val_loss: 0.0692 - learning_rate: 3.0000e-04
# Epoch 19/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9789 - loss: 0.1239 - val_accuracy: 1.0000 - val_loss: 0.0603 - learning_rate: 3.0000e-04
# Epoch 20/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9824 - loss: 0.1390 - val_accuracy: 1.0000 - val_loss: 0.0533 - learning_rate: 3.0000e-04
# Epoch 21/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9789 - loss: 0.1362 - val_accuracy: 1.0000 - val_loss: 0.0480 - learning_rate: 3.0000e-04
# Epoch 22/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9754 - loss: 0.1151 - val_accuracy: 1.0000 - val_loss: 0.0436 - learning_rate: 3.0000e-04
# Epoch 23/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9859 - loss: 0.1229 - val_accuracy: 1.0000 - val_loss: 0.0395 - learning_rate: 3.0000e-04
# Epoch 24/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9894 - loss: 0.1091 - val_accuracy: 1.0000 - val_loss: 0.0361 - learning_rate: 3.0000e-04
# Epoch 25/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9930 - loss: 0.1060 - val_accuracy: 1.0000 - val_loss: 0.0329 - learning_rate: 3.0000e-04
# Epoch 26/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9930 - loss: 0.0930 - val_accuracy: 1.0000 - val_loss: 0.0306 - learning_rate: 3.0000e-04
# Epoch 27/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9965 - loss: 0.0869 - val_accuracy: 1.0000 - val_loss: 0.0288 - learning_rate: 3.0000e-04
# Epoch 28/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9859 - loss: 0.1124 - val_accuracy: 1.0000 - val_loss: 0.0274 - learning_rate: 3.0000e-04
# Epoch 29/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9894 - loss: 0.0863 - val_accuracy: 1.0000 - val_loss: 0.0263 - learning_rate: 3.0000e-04
# Epoch 30/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9859 - loss: 0.0884 - val_accuracy: 1.0000 - val_loss: 0.0258 - learning_rate: 3.0000e-04
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Fold 4 best val accuracy: 1.0000
# Fold 4 best val loss: 0.0258
# ════════════════════════════════════════════════════════════
# FOLD 5 / 5
# Train: 72 samples | Val: 17 samples
# ════════════════════════════════════════════════════════════
#  Augmented training size: 288
# Epoch 1/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - accuracy: 0.5729 - loss: 0.9086 - val_accuracy: 0.8824 - val_loss: 0.8979 - learning_rate: 3.0000e-04
# Epoch 2/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7118 - loss: 0.6818 - val_accuracy: 1.0000 - val_loss: 0.7817 - learning_rate: 3.0000e-04
# Epoch 3/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8681 - loss: 0.4866 - val_accuracy: 1.0000 - val_loss: 0.6810 - learning_rate: 3.0000e-04
# Epoch 4/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9028 - loss: 0.4143 - val_accuracy: 1.0000 - val_loss: 0.5839 - learning_rate: 3.0000e-04
# Epoch 5/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9340 - loss: 0.3545 - val_accuracy: 1.0000 - val_loss: 0.4954 - learning_rate: 3.0000e-04
# Epoch 6/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9514 - loss: 0.2707 - val_accuracy: 1.0000 - val_loss: 0.4199 - learning_rate: 3.0000e-04
# Epoch 7/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9757 - loss: 0.2489 - val_accuracy: 1.0000 - val_loss: 0.3482 - learning_rate: 3.0000e-04
# Epoch 8/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9688 - loss: 0.2295 - val_accuracy: 1.0000 - val_loss: 0.2843 - learning_rate: 3.0000e-04
# Epoch 9/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9826 - loss: 0.1941 - val_accuracy: 1.0000 - val_loss: 0.2308 - learning_rate: 3.0000e-04
# Epoch 10/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9861 - loss: 0.1739 - val_accuracy: 1.0000 - val_loss: 0.1874 - learning_rate: 3.0000e-04
# Epoch 11/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9896 - loss: 0.1585 - val_accuracy: 1.0000 - val_loss: 0.1499 - learning_rate: 3.0000e-04
# Epoch 12/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9896 - loss: 0.1439 - val_accuracy: 1.0000 - val_loss: 0.1200 - learning_rate: 3.0000e-04
# Epoch 13/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9896 - loss: 0.1303 - val_accuracy: 1.0000 - val_loss: 0.0967 - learning_rate: 3.0000e-04
# Epoch 14/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9861 - loss: 0.1356 - val_accuracy: 1.0000 - val_loss: 0.0784 - learning_rate: 3.0000e-04
# Epoch 15/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9896 - loss: 0.1033 - val_accuracy: 1.0000 - val_loss: 0.0640 - learning_rate: 3.0000e-04
# Epoch 16/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9965 - loss: 0.0941 - val_accuracy: 1.0000 - val_loss: 0.0540 - learning_rate: 3.0000e-04
# Epoch 17/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9931 - loss: 0.1083 - val_accuracy: 1.0000 - val_loss: 0.0455 - learning_rate: 3.0000e-04
# Epoch 18/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9931 - loss: 0.0836 - val_accuracy: 1.0000 - val_loss: 0.0393 - learning_rate: 3.0000e-04
# Epoch 19/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 0.0790 - val_accuracy: 1.0000 - val_loss: 0.0348 - learning_rate: 3.0000e-04
# Epoch 20/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9965 - loss: 0.0847 - val_accuracy: 1.0000 - val_loss: 0.0311 - learning_rate: 3.0000e-04
# Epoch 21/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 0.0707 - val_accuracy: 1.0000 - val_loss: 0.0283 - learning_rate: 3.0000e-04
# Epoch 22/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9896 - loss: 0.0874 - val_accuracy: 1.0000 - val_loss: 0.0260 - learning_rate: 3.0000e-04
# Epoch 23/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9931 - loss: 0.0806 - val_accuracy: 1.0000 - val_loss: 0.0245 - learning_rate: 3.0000e-04
# Epoch 24/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9896 - loss: 0.0680 - val_accuracy: 1.0000 - val_loss: 0.0231 - learning_rate: 3.0000e-04
# Epoch 25/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9965 - loss: 0.0626 - val_accuracy: 1.0000 - val_loss: 0.0220 - learning_rate: 3.0000e-04
# Epoch 26/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9965 - loss: 0.0612 - val_accuracy: 1.0000 - val_loss: 0.0211 - learning_rate: 3.0000e-04
# Epoch 27/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9896 - loss: 0.0672 - val_accuracy: 1.0000 - val_loss: 0.0202 - learning_rate: 3.0000e-04
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Fold 5 best val accuracy: 1.0000
# Fold 5 best val loss: 0.0202

# %% [markdown]
# ## 5 Fold CV Training Curves

# %%
fig, axes = plt.subplots(2, N_FOLDS, figsize=(18, 8))
fig.suptitle("Training Curves per Fold", fontsize=14, fontweight="bold")

for fold_idx, hist in enumerate(fold_histories):
    epochs_ran = range(1, len(hist["accuracy"]) + 1)

    axes[0, fold_idx].plot(epochs_ran, hist["accuracy"],     label="Train acc", color="steelblue")
    axes[0, fold_idx].plot(epochs_ran, hist["val_accuracy"], label="Val acc",   color="tomato")
    axes[0, fold_idx].set_title(f"Fold {fold_idx+1}")
    axes[0, fold_idx].set_ylim([0, 1.05])
    axes[0, fold_idx].legend(fontsize=8)
    if fold_idx == 0:
        axes[0, fold_idx].set_ylabel("Accuracy")

    axes[1, fold_idx].plot(epochs_ran, hist["loss"],     label="Train loss", color="steelblue")
    axes[1, fold_idx].plot(epochs_ran, hist["val_loss"], label="Val loss",   color="tomato")
    axes[1, fold_idx].legend(fontsize=8)
    if fold_idx == 0:
        axes[1, fold_idx].set_ylabel("Loss")
    axes[1, fold_idx].set_xlabel("Epoch")

plt.tight_layout()
plt.savefig("training_curves.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Ensemble 5 Fold Best Predictions
#
# We Previously trained 5 models on
# * 80% of the data
#
# Now we can test on the 20% validation set and calcuate model accuracy

# %%
oof_preds  = np.zeros((len(labels), N_CLASSES))  # out-of-fold softmax probs
oof_labels = labels.copy()

for fold_idx, (train_idx, val_idx) in enumerate(skf.split(ir_frames, labels)):
    ckpt_path = os.path.join(CHECKPOINT_DIR, f"fold_{fold_idx}_best.keras")
    fold_model = tf.keras.models.load_model(ckpt_path)

    ir_val_raw  = ir_frames[val_idx]
    gas_val_raw = gas[val_idx]

    # Make IR relative before recomputing norm stats
    ir_train_rel = make_ir_relative(ir_frames[train_idx])  # <-- add
    ir_val_rel   = make_ir_relative(ir_val_raw)            # <-- add

    # Recompute norm stats on relative IR — must match training loop
    ir_mean, ir_std, gas_mean, gas_std = compute_normalization_stats(
        ir_train_rel, gas[train_idx]   # <-- was ir_frames[train_idx]
    )
    ir_val_norm, gas_val_norm = normalize(
        ir_val_rel, gas_val_raw, ir_mean, ir_std, gas_mean, gas_std  # <-- was ir_val_raw
    )

    preds = fold_model.predict(
        {"ir_frames": ir_val_norm, "gas": gas_val_norm}, verbose=0
    )
    oof_preds[val_idx] = preds
    print(f"Fold {fold_idx+1} OOF predictions collected.")

oof_pred_classes = np.argmax(oof_preds, axis=1)
oof_accuracy = (oof_pred_classes == oof_labels).mean()
print(f"Out-of-fold ensemble accuracy: {oof_accuracy:.4f}")
# Out:
# Fold 1 OOF predictions collected.
# Fold 2 OOF predictions collected.
# Fold 3 OOF predictions collected.
# Fold 4 OOF predictions collected.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7eae910eed40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Fold 5 OOF predictions collected.
# Out-of-fold ensemble accuracy: 1.0000

# %% [markdown]
# ## Confusion matrix

# %%
print("\n" + "═"*50)
print("CLASSIFICATION REPORT (Out-of-Fold)")
print("═"*50)
print(classification_report(
    oof_labels, oof_pred_classes,
    target_names=CLASS_NAMES
))

# ── Confusion Matrix ──────────────────────────────────────────────────────────
cm = confusion_matrix(oof_labels, oof_pred_classes)
fig, ax = plt.subplots(figsize=(7, 6))
sns.heatmap(
    cm, annot=True, fmt="d", cmap="Blues",
    xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
    linewidths=0.5, ax=ax
)
ax.set_xlabel("Predicted", fontweight="bold")
ax.set_ylabel("True",      fontweight="bold")
ax.set_title(f"Confusion Matrix (OOF) — Accuracy: {oof_accuracy:.2%}", fontweight="bold")
plt.tight_layout()
plt.savefig("confusion_matrix.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# ══════════════════════════════════════════════════
# CLASSIFICATION REPORT (Out-of-Fold)
# ══════════════════════════════════════════════════
#               precision    recall  f1-score   support
#
#      aerosol       1.00      1.00      1.00        30
#        flame       1.00      1.00      1.00        29
#       normal       1.00      1.00      1.00        30
#
#     accuracy                           1.00        89
#    macro avg       1.00      1.00      1.00        89
# weighted avg       1.00      1.00      1.00        89

# %% [markdown]
# # Train Deployment Model on Full Dataset
#
# This is the model used for deployment. It trains on all 120 samples. The number of epochs is decided by looking at when the validation loss plateaued across the 5 folds.

# %%
# Compute the normalization stats on the full dataset
# Make full dataset relative before norm stats and augmentation
ir_rel_full = make_ir_relative(ir_frames)  # (N, 20, 32, 24)

ir_mean_full, ir_std_full, gas_mean_full, gas_std_full = compute_normalization_stats(
    ir_rel_full, gas
)
ir_norm_full, gas_norm_full = normalize(
    ir_rel_full, gas, ir_mean_full, ir_std_full, gas_mean_full, gas_std_full
)

# Augement the full dataset
ir_full_aug, gas_full_aug = augment_batch(
    ir_norm_full, gas_norm_full, n_aug_per_sample=4, seed=SEED
)

# Shuffle the dataset
y_full_aug = np.tile(labels, 5)
perm = np.random.permutation(len(y_full_aug))
ir_full_aug  = ir_full_aug[perm]
gas_full_aug = gas_full_aug[perm]
y_full_aug   = y_full_aug[perm]

# Estimate good epoch count from CV (average of best epochs)
avg_best_epoch = int(np.mean([
    np.argmax(h["val_accuracy"]) + 1 for h in fold_histories
]))

# Add a small buffer since we now have more data
# FINAL_EPOCHS = int(avg_best_epoch * 1.4)
FINAL_EPOCHS = 6 # hardcoding for now as num of epochs is very low

print(f"Training final model for {FINAL_EPOCHS} epochs (CV mean best: {avg_best_epoch})")

final_model = build_model(l2_lambda=L2_LAMBDA)
final_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

final_ckpt = os.path.join(CHECKPOINT_DIR, "final_model.keras")

final_history = final_model.fit(x={"ir_frames": ir_full_aug, "gas": gas_full_aug},
      y=y_full_aug, epochs=FINAL_EPOCHS, batch_size=BATCH_SIZE,
      callbacks=[
          tf.keras.callbacks.ModelCheckpoint(
              final_ckpt, monitor="accuracy", save_best_only=True, verbose=0
          ),
          tf.keras.callbacks.ReduceLROnPlateau(
              monitor="loss", factor=0.5, patience=10, min_lr=1e-6, verbose=1
          )
      ],
      verbose=1
)

final_model = tf.keras.models.load_model(final_ckpt)
print("Final model trained and saved.")
# Out:
# Training final model for 6 epochs (CV mean best: 4)
# Epoch 1/6
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.4517 - loss: 1.2833 - learning_rate: 3.0000e-04
# Epoch 2/6
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.5843 - loss: 0.8779 - learning_rate: 3.0000e-04
# Epoch 3/6
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7011 - loss: 0.6830 - learning_rate: 3.0000e-04
# Epoch 4/6
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8112 - loss: 0.5064 - learning_rate: 3.0000e-04
# Epoch 5/6
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8787 - loss: 0.4013 - learning_rate: 3.0000e-04
# Epoch 6/6
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9146 - loss: 0.3183 - learning_rate: 3.0000e-04
# Final model trained and saved.

# %%
# final_history
fig, axes = plt.subplots(figsize=(7, 6))
axes.set_title(f"Training Curve", fontweight="bold")

epochs_ran = range(1, len(final_history.history["accuracy"]) + 1)

axes.plot(epochs_ran, final_history.history["loss"], label="Train loss", color="steelblue")
axes.plot(epochs_ran, final_history.history["accuracy"], label="Accuracy",   color="tomato")

axes.set_ylim(0, 1)
axes.set_xlabel("Epoch")
axes.set_ylabel("Accuracy")

axes.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Save Normalisation Statistics
#
# The mean/std used to normalise inputs must be saved and deployed alongside the model.

# %%
STATS_PATH = "/content/drive/MyDrive/gas-detector-model/model_stats/"
os.makedirs(STATS_PATH, exist_ok=True)

np.savez(
    f"{STATS_PATH}/norm_statsv2.npz",
    ir_mean=ir_mean_full,
    ir_std=ir_std_full,
    gas_mean=gas_mean_full,
    gas_std=gas_std_full
)

# Convert to CSV
df = pd.DataFrame({
    "ir_mean": [ir_mean_full.tolist()],
    "ir_std": [ir_std_full.tolist()],
    "gas_mean": [gas_mean_full.tolist()],
    "gas_std": [gas_std_full.tolist()],
})

df.to_csv(f"{STATS_PATH}/norm_statsv2.csv", index=False)

print(f"Normalisation stats saved")

print(f"  ir_mean shape  : {ir_mean_full.shape}")
print(f"  ir_std shape   : {ir_std_full.shape}")
print(f"  gas_mean shape : {gas_mean_full.shape}")
print(f"  gas_std shape  : {gas_std_full.shape}")
# Out:
# Normalisation stats saved
#   ir_mean shape  : (1, 1, 32, 24)
#   ir_std shape   : (1, 1, 32, 24)
#   gas_mean shape : (1, 1, 3)
#   gas_std shape  : (1, 1, 3)

# %% [markdown]
# ## TFlite Conversion & Quantisation
#
# Export 2 variants of the model and compare accuracy
# 1. Float32: 214.9 KB
# 2. Float16: 193.4 KB

# %%
import keras
TFLITE_DIR = "/content/drive/MyDrive/gas-detector-model/tflite_models"
os.makedirs(TFLITE_DIR, exist_ok=True)

# Load trained model (may use CuDNN GRU if GPU is visible)
print("Loading trained model...")
trained_model = keras.models.load_model("/content/checkpoints/final_model.keras", compile=False)

# Build a CPU-compatible version of the model and transfer weights
print("Building CPU-compatible model and transferring weights...")
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
export_model = build_model(tflite_export=True)
export_model.set_weights(trained_model.get_weights())

# Export to SavedModel format
print("Exporting to SavedModel...")
export_model.export("saved_model_cpu")

def convert(path, desc, optimizations=None, float16=False):
    converter = tf.lite.TFLiteConverter.from_saved_model("saved_model_cpu")

    # Standard ops only - if this fails, the model still has dynamic ops
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS]

    if optimizations:
        converter.optimizations = optimizations
    if float16:
        converter.target_spec.supported_types = [tf.float16]

    tflite_model = converter.convert()

    with open(path, "wb") as f:
        f.write(tflite_model)
    print(f"{desc}: {os.path.getsize(path)/1024:.1f} KB")
    return tflite_model

# Float32 (baseline)
tflite_f32 = convert(
    f"{TFLITE_DIR}/model_float32v2.tflite",
    "Float32"
)

# Float16
tflite_f16 = convert(
    f"{TFLITE_DIR}/model_float16v2.tflite",
    "Float16",
    optimizations=[tf.lite.Optimize.DEFAULT],
    float16=True
)
# Out:
# Loading trained model...
# Building CPU-compatible model and transferring weights...
# Exporting to SavedModel...
# Saved artifact at 'saved_model_cpu'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): Dict[['ir_frames', TensorSpec(shape=(None, 20, 32, 24), dtype=tf.float32, name='ir_frames')], ['gas', TensorSpec(shape=(None, 20, 3), dtype=tf.float32, name='gas')]]
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   139288177393296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139291327214224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139287136144464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139287136155600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139287136152528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139287136152336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501752912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501753488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501756176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501757136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501756944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501755600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501753104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501753872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501756752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501755408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501754256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501755216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501754064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501754832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501753296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501758288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501758096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501755984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501756368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501754640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501754448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501758672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501758480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501757520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501759632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501759440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501758864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501760016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139286501759824: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Float32: 198.4 KB
# Float16: 185.1 KB

# %% [markdown]
# # Inspect tflite file operations
#
# The inspection output shows the model fully unrolled and converted to pure TFLite ops. Here's what you're seeing:
#
# Inputs (indices 0-1)
# Two named inputs matching exactly what was defined in build_model:
#
# serving_default_gas:0 → shape [1, 20, 3]
# serving_default_ir_frames:0 → shape [1, 20, 32, 24]
#
# The batch dimension is fixed at 1, meaning the model is optimised for single-sample inference.
#
# Output (index 457 → StatefulPartitionedCall_1:0)
# Shape [1, 4] — one probability per class, softmax already applied. You just take argmax to get the predicted class.
#
# Weights/constants (indices 2-34)
# The fused layer weights — notice TFLite has merged BatchNorm into the preceding Conv layers (e.g. index 4 shows td_conv2 and batch_normalization_61 fused together). This is a TFLite optimisation called operator fusion — it eliminates the separate BN multiply/add at runtime by baking the BN parameters directly into the conv weights, making inference faster.
#
# GRU unrolled (indices 54-455)
# This is the big block — you can see the GRU is literally repeated 20 times (Tanh_0 through Tanh_19, Sigmoid_0 through Sigmoid_39, etc.), one full GRU cell computation per timestep. Each timestep has the same pattern:
#
# MatMul → split (z, r, h gates) → Sigmoid → Sigmoid → mul → Tanh → add
#
# This is exactly what unroll=True does — it trades graph size for no dynamic ops. The 127 KB vs 68 KB size difference is entirely from this repetition.

# %%
def inspect_tflite(path):
    interpreter = tf.lite.Interpreter(model_path=path)
    interpreter.allocate_tensors()

    print(f"\n{'='*50}")
    print(f"Model: {path}")
    print(f"{'='*50}")

    print("\n--- Inputs ---")
    for t in interpreter.get_input_details():
        print(f"  {t['name']}: shape={t['shape']}, dtype={t['dtype']}")

    print("\n--- Outputs ---")
    for t in interpreter.get_output_details():
        print(f"  {t['name']}: shape={t['shape']}, dtype={t['dtype']}")

    print("\n--- All Tensors ---")
    for t in interpreter.get_tensor_details():
        print(f"  [{t['index']:3d}] {t['name']:<60} shape={t['shape']}, dtype={t['dtype']}")

inspect_tflite(f"{TFLITE_DIR}/model_float32.tflite")
inspect_tflite(f"{TFLITE_DIR}/model_float16.tflite")
# Out:
# ==================================================
# Model: /content/drive/MyDrive/gas-detector-model/tflite_models/model_float32.tflite
# ==================================================
#
# --- Inputs ---
#   serving_default_gas:0: shape=[ 1 20  3], dtype=<class 'numpy.float32'>
#   serving_default_ir_frames:0: shape=[ 1 20 32 24], dtype=<class 'numpy.float32'>
#
# --- Outputs ---
#   StatefulPartitionedCall_1:0: shape=[1 3], dtype=<class 'numpy.float32'>
#
# --- All Tensors ---
#   [  0] serving_default_gas:0                                        shape=[ 1 20  3], dtype=<class 'numpy.float32'>
#   [  1] serving_default_ir_frames:0                                  shape=[ 1 20 32 24], dtype=<class 'numpy.float32'>
#   [  2] arith.constant                                               shape=[32], dtype=<class 'numpy.float32'>
#   [  3] arith.constant1                                              shape=[16], dtype=<class 'numpy.float32'>
#   [  4] arith.constant2                                              shape=[32  1  3 16], dtype=<class 'numpy.float32'>
#   [  5] arith.constant3                                              shape=[16  1  3  3], dtype=<class 'numpy.float32'>
#   [  6] arith.constant4                                              shape=[64], dtype=<class 'numpy.float32'>
#   [  7] arith.constant5                                              shape=[64 48], dtype=<class 'numpy.float32'>
#   [  8] arith.constant6                                              shape=[16], dtype=<class 'numpy.float32'>
#   [  9] arith.constant7                                              shape=[8], dtype=<class 'numpy.float32'>
#   [ 10] arith.constant8                                              shape=[3], dtype=<class 'numpy.int32'>
#   [ 11] arith.constant9                                              shape=[3], dtype=<class 'numpy.int32'>
#   [ 12] arith.constant10                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 13] arith.constant11                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 14] arith.constant12                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 15] arith.constant13                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 16] arith.constant14                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 17] arith.constant15                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 18] arith.constant16                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 19] arith.constant17                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 20] arith.constant18                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 21] arith.constant19                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 22] arith.constant20                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 23] arith.constant21                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 24] arith.constant22                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 25] arith.constant23                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 26] arith.constant24                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 27] arith.constant25                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 28] arith.constant26                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 29] arith.constant27                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 30] arith.constant28                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 31] arith.constant29                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 32] arith.constant30                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 33] arith.constant31                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 34] arith.constant32                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 35] arith.constant33                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 36] arith.constant34                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 37] arith.constant35                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 38] arith.constant36                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 39] arith.constant37                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 40] arith.constant38                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 41] arith.constant39                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 42] arith.constant40                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 43] arith.constant41                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 44] arith.constant42                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 45] arith.constant43                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 46] arith.constant44                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 47] arith.constant45                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 48] arith.constant46                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 49] arith.constant47                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 50] arith.constant48                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 51] arith.constant49                                             shape=[16  3  3  8], dtype=<class 'numpy.float32'>
#   [ 52] arith.constant50                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 53] arith.constant51                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 54] arith.constant52                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 55] arith.constant53                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 56] arith.constant54                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 57] arith.constant55                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 58] arith.constant56                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 59] arith.constant57                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 60] arith.constant58                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 61] arith.constant59                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 62] arith.constant60                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 63] arith.constant61                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 64] arith.constant62                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 65] arith.constant63                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 66] arith.constant64                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 67] arith.constant65                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 68] arith.constant66                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 69] arith.constant67                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 70] arith.constant68                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 71] arith.constant69                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 72] arith.constant70                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 73] arith.constant71                                             shape=[8 3 3 1], dtype=<class 'numpy.float32'>
#   [ 74] arith.constant72                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 75] arith.constant73                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 76] arith.constant74                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 77] arith.constant75                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 78] arith.constant76                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 79] arith.constant77                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 80] arith.constant78                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 81] arith.constant79                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 82] arith.constant80                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 83] arith.constant81                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 84] arith.constant82                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 85] arith.constant83                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 86] arith.constant84                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 87] arith.constant85                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 88] arith.constant86                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 89] arith.constant87                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 90] arith.constant88                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 91] arith.constant89                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 92] arith.constant90                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 93] arith.constant91                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 94] arith.constant92                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 95] arith.constant93                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 96] arith.constant94                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 97] arith.constant95                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 98] arith.constant96                                             shape=[5], dtype=<class 'numpy.int32'>
#   [ 99] arith.constant97                                             shape=[5], dtype=<class 'numpy.int32'>
#   [100] arith.constant98                                             shape=[5], dtype=<class 'numpy.int32'>
#   [101] arith.constant99                                             shape=[5], dtype=<class 'numpy.int32'>
#   [102] arith.constant100                                            shape=[5], dtype=<class 'numpy.int32'>
#   [103] arith.constant101                                            shape=[5], dtype=<class 'numpy.int32'>
#   [104] arith.constant102                                            shape=[5], dtype=<class 'numpy.int32'>
#   [105] arith.constant103                                            shape=[5], dtype=<class 'numpy.int32'>
#   [106] arith.constant104                                            shape=[5], dtype=<class 'numpy.int32'>
#   [107] arith.constant105                                            shape=[5], dtype=<class 'numpy.int32'>
#   [108] arith.constant106                                            shape=[5], dtype=<class 'numpy.int32'>
#   [109] arith.constant107                                            shape=[5], dtype=<class 'numpy.int32'>
#   [110] arith.constant108                                            shape=[5], dtype=<class 'numpy.int32'>
#   [111] arith.constant109                                            shape=[5], dtype=<class 'numpy.int32'>
#   [112] arith.constant110                                            shape=[5], dtype=<class 'numpy.int32'>
#   [113] arith.constant111                                            shape=[5], dtype=<class 'numpy.int32'>
#   [114] arith.constant112                                            shape=[5], dtype=<class 'numpy.int32'>
#   [115] arith.constant113                                            shape=[ 3 64], dtype=<class 'numpy.float32'>
#   [116] arith.constant114                                            shape=[48 16], dtype=<class 'numpy.float32'>
#   [117] arith.constant115                                            shape=[48 16], dtype=<class 'numpy.float32'>
#   [118] arith.constant116                                            shape=[16], dtype=<class 'numpy.float32'>
#   [119] arith.constant117                                            shape=[16], dtype=<class 'numpy.float32'>
#   [120] arith.constant118                                            shape=[8], dtype=<class 'numpy.float32'>
#   [121] arith.constant119                                            shape=[8], dtype=<class 'numpy.float32'>
#   [122] arith.constant120                                            shape=[48], dtype=<class 'numpy.float32'>
#   [123] arith.constant121                                            shape=[48], dtype=<class 'numpy.float32'>
#   [124] arith.constant122                                            shape=[3], dtype=<class 'numpy.float32'>
#   [125] arith.constant123                                            shape=[], dtype=<class 'numpy.int32'>
#   [126] arith.constant124                                            shape=[], dtype=<class 'numpy.int32'>
#   [127] arith.constant125                                            shape=[], dtype=<class 'numpy.int32'>
#   [128] arith.constant126                                            shape=[2], dtype=<class 'numpy.int32'>
#   [129] arith.constant127                                            shape=[2], dtype=<class 'numpy.int32'>
#   [130] arith.constant128                                            shape=[2], dtype=<class 'numpy.int32'>
#   [131] arith.constant129                                            shape=[2], dtype=<class 'numpy.int32'>
#   [132] arith.constant130                                            shape=[], dtype=<class 'numpy.float32'>
#   [133] arith.constant131                                            shape=[1], dtype=<class 'numpy.int32'>
#   [134] arith.constant132                                            shape=[1], dtype=<class 'numpy.int32'>
#   [135] arith.constant133                                            shape=[3], dtype=<class 'numpy.int32'>
#   [136] SensorFusionClassifier_1/ir_gru_1/zeros/Const                shape=[], dtype=<class 'numpy.float32'>
#   [137] SensorFusionClassifier_1/ir_gru_1/zeros/packed/1             shape=[], dtype=<class 'numpy.int32'>
#   [138] SensorFusionClassifier_1/reshape_11_1/Reshape/shape/1        shape=[], dtype=<class 'numpy.int32'>
#   [139] SensorFusionClassifier_1/reshape_11_1/Reshape/shape/2        shape=[], dtype=<class 'numpy.int32'>
#   [140] SensorFusionClassifier_1/reshape_11_1/Reshape/shape/3        shape=[], dtype=<class 'numpy.int32'>
#   [141] arith.constant134                                            shape=[5], dtype=<class 'numpy.int32'>
#   [142] arith.constant135                                            shape=[2], dtype=<class 'numpy.int32'>
#   [143] SensorFusionClassifier_1/gas_conv1_1/convolution/ExpandDims  shape=[ 1  1 20  3], dtype=<class 'numpy.float32'>
#   [144] SensorFusionClassifier_1/reshape_11_1/Shape                  shape=[4], dtype=<class 'numpy.int32'>
#   [145] SensorFusionClassifier_1/reshape_11_1/strided_slice          shape=[], dtype=<class 'numpy.int32'>
#   [146] SensorFusionClassifier_1/reshape_11_1/Reshape/shape          shape=[5], dtype=<class 'numpy.int32'>
#   [147] SensorFusionClassifier_1/reshape_11_1/Reshape                shape=[ 1 20 32 24  1], dtype=<class 'numpy.float32'>
#   [148] SensorFusionClassifier_1/td_conv1_1/transpose                shape=[20  1 32 24  1], dtype=<class 'numpy.float32'>
#   [149] SensorFusionClassifier_1/td_conv1_1/strided_slice_1          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [150] SensorFusionClassifier_1/td_conv1_1/strided_slice_10         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [151] SensorFusionClassifier_1/td_conv1_1/strided_slice_11         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [152] SensorFusionClassifier_1/td_conv1_1/strided_slice_12         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [153] SensorFusionClassifier_1/td_conv1_1/strided_slice_13         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [154] SensorFusionClassifier_1/td_conv1_1/strided_slice_14         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [155] SensorFusionClassifier_1/td_conv1_1/strided_slice_15         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [156] SensorFusionClassifier_1/td_conv1_1/strided_slice_16         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [157] SensorFusionClassifier_1/td_conv1_1/strided_slice_17         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [158] SensorFusionClassifier_1/td_conv1_1/strided_slice_18         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [159] SensorFusionClassifier_1/td_conv1_1/strided_slice_19         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [160] SensorFusionClassifier_1/td_conv1_1/strided_slice_2          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [161] SensorFusionClassifier_1/td_conv1_1/strided_slice_20         shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [162] SensorFusionClassifier_1/td_conv1_1/strided_slice_3          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [163] SensorFusionClassifier_1/td_conv1_1/strided_slice_4          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [164] SensorFusionClassifier_1/td_conv1_1/strided_slice_5          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [165] SensorFusionClassifier_1/td_conv1_1/strided_slice_6          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [166] SensorFusionClassifier_1/td_conv1_1/strided_slice_7          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [167] SensorFusionClassifier_1/td_conv1_1/strided_slice_8          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [168] SensorFusionClassifier_1/td_conv1_1/strided_slice_9          shape=[ 1 32 24  1], dtype=<class 'numpy.float32'>
#   [169] SensorFusionClassifier_1/re_lu_54_1/Relu;SensorFusionClassifier_1/batch_normalization_54_1/batchnorm/add_1;SensorFusionClassifier_1/gas_conv1_1/convolution/Squeeze;SensorFusionClassifier_1/batch_normalization_54_1/batchnorm/mul_1;SensorFusionClassifier_1/gas_conv1_1/BiasAdd;;SensorFusionClassifier_1/gas_conv1_1/convolution shape=[ 1  1 20 16], dtype=<class 'numpy.float32'>
#   [170] SensorFusionClassifier_1/re_lu_54_1/Relu;SensorFusionClassifier_1/batch_normalization_54_1/batchnorm/add_1;SensorFusionClassifier_1/gas_conv1_1/convolution/Squeeze;SensorFusionClassifier_1/batch_normalization_54_1/batchnorm/mul_1;SensorFusionClassifier_1/gas_conv1_1/BiasAdd; shape=[ 1 20 16], dtype=<class 'numpy.float32'>
#   [171] SensorFusionClassifier_1/gas_conv2_1/convolution/ExpandDims  shape=[ 1  1 20 16], dtype=<class 'numpy.float32'>
#   [172] SensorFusionClassifier_1/re_lu_55_1/Relu;SensorFusionClassifier_1/batch_normalization_55_1/batchnorm/add_1;SensorFusionClassifier_1/gas_conv2_1/convolution/Squeeze;SensorFusionClassifier_1/batch_normalization_55_1/batchnorm/mul_1;SensorFusionClassifier_1/gas_conv2_1/BiasAdd;;SensorFusionClassifier_1/gas_conv2_1/convolution shape=[ 1  1 20 32], dtype=<class 'numpy.float32'>
#   [173] SensorFusionClassifier_1/re_lu_55_1/Relu;SensorFusionClassifier_1/batch_normalization_55_1/batchnorm/add_1;SensorFusionClassifier_1/gas_conv2_1/convolution/Squeeze;SensorFusionClassifier_1/batch_normalization_55_1/batchnorm/mul_1;SensorFusionClassifier_1/gas_conv2_1/BiasAdd; shape=[ 1 20 32], dtype=<class 'numpy.float32'>
#   [174] SensorFusionClassifier_1/gas_gap_1/Mean                      shape=[ 1 32], dtype=<class 'numpy.float32'>
#   [175] SensorFusionClassifier_1/td_conv1_1/BiasAdd;SensorFusionClassifier_1/td_conv1_1/convolution; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [176] SensorFusionClassifier_1/td_conv1_1/BiasAdd_1;SensorFusionClassifier_1/td_conv1_1/convolution_1; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [177] SensorFusionClassifier_1/td_conv1_1/BiasAdd_10;SensorFusionClassifier_1/td_conv1_1/convolution_10; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [178] SensorFusionClassifier_1/td_conv1_1/BiasAdd_11;SensorFusionClassifier_1/td_conv1_1/convolution_11; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [179] SensorFusionClassifier_1/td_conv1_1/BiasAdd_12;SensorFusionClassifier_1/td_conv1_1/convolution_12; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [180] SensorFusionClassifier_1/td_conv1_1/BiasAdd_13;SensorFusionClassifier_1/td_conv1_1/convolution_13; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [181] SensorFusionClassifier_1/td_conv1_1/BiasAdd_14;SensorFusionClassifier_1/td_conv1_1/convolution_14; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [182] SensorFusionClassifier_1/td_conv1_1/BiasAdd_15;SensorFusionClassifier_1/td_conv1_1/convolution_15; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [183] SensorFusionClassifier_1/td_conv1_1/BiasAdd_16;SensorFusionClassifier_1/td_conv1_1/convolution_16; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [184] SensorFusionClassifier_1/td_conv1_1/BiasAdd_17;SensorFusionClassifier_1/td_conv1_1/convolution_17; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [185] SensorFusionClassifier_1/td_conv1_1/BiasAdd_18;SensorFusionClassifier_1/td_conv1_1/convolution_18; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [186] SensorFusionClassifier_1/td_conv1_1/BiasAdd_19;SensorFusionClassifier_1/td_conv1_1/convolution_19; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [187] SensorFusionClassifier_1/td_conv1_1/BiasAdd_2;SensorFusionClassifier_1/td_conv1_1/convolution_2; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [188] SensorFusionClassifier_1/td_conv1_1/BiasAdd_3;SensorFusionClassifier_1/td_conv1_1/convolution_3; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [189] SensorFusionClassifier_1/td_conv1_1/BiasAdd_4;SensorFusionClassifier_1/td_conv1_1/convolution_4; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [190] SensorFusionClassifier_1/td_conv1_1/BiasAdd_5;SensorFusionClassifier_1/td_conv1_1/convolution_5; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [191] SensorFusionClassifier_1/td_conv1_1/BiasAdd_6;SensorFusionClassifier_1/td_conv1_1/convolution_6; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [192] SensorFusionClassifier_1/td_conv1_1/BiasAdd_7;SensorFusionClassifier_1/td_conv1_1/convolution_7; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [193] SensorFusionClassifier_1/td_conv1_1/BiasAdd_8;SensorFusionClassifier_1/td_conv1_1/convolution_8; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [194] SensorFusionClassifier_1/td_conv1_1/BiasAdd_9;SensorFusionClassifier_1/td_conv1_1/convolution_9; shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [195] SensorFusionClassifier_1/td_conv1_1/stack                    shape=[20  1 32 24  8], dtype=<class 'numpy.float32'>
#   [196] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [197] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_10 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [198] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_11 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [199] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_12 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [200] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_13 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [201] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_14 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [202] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_15 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [203] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_16 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [204] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_17 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [205] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_18 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [206] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_19 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [207] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_2 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [208] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_20 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [209] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_3 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [210] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_4 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [211] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_5 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [212] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_6 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [213] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_7 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [214] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_8 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [215] SensorFusionClassifier_1/time_distributed_44_1/strided_slice_9 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [216] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_2/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [217] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_3/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [218] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_4/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [219] SensorFusionClassifier_1/time_distributed_44_1/batchnorm/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [220] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_5/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [221] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_6/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [222] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_7/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [223] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_8/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [224] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_9/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [225] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_10/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [226] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_11/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [227] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_12/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [228] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_13/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [229] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_14/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [230] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_1/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [231] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_15/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [232] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_16/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [233] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_17/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [234] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_18/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [235] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_19/mul_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [236] SensorFusionClassifier_1/time_distributed_44_1/batchnorm/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [237] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_3/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [238] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_4/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [239] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_5/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [240] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_6/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [241] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_7/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [242] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_8/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [243] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_9/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [244] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_1/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [245] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_10/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [246] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_11/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [247] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_12/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [248] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_13/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [249] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_14/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [250] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_15/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [251] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_16/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [252] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_17/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [253] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_18/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [254] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_19/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [255] SensorFusionClassifier_1/time_distributed_44_1/batchnorm_2/add_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [256] SensorFusionClassifier_1/time_distributed_44_1/stack         shape=[20  1 32 24  8], dtype=<class 'numpy.float32'>
#   [257] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_1 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [258] SensorFusionClassifier_1/time_distributed_45_1/Relu          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [259] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_10 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [260] SensorFusionClassifier_1/time_distributed_45_1/Relu_9        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [261] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_11 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [262] SensorFusionClassifier_1/time_distributed_45_1/Relu_10       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [263] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_12 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [264] SensorFusionClassifier_1/time_distributed_45_1/Relu_11       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [265] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_13 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [266] SensorFusionClassifier_1/time_distributed_45_1/Relu_12       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [267] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_14 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [268] SensorFusionClassifier_1/time_distributed_45_1/Relu_13       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [269] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_15 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [270] SensorFusionClassifier_1/time_distributed_45_1/Relu_14       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [271] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_16 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [272] SensorFusionClassifier_1/time_distributed_45_1/Relu_15       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [273] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_17 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [274] SensorFusionClassifier_1/time_distributed_45_1/Relu_16       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [275] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_18 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [276] SensorFusionClassifier_1/time_distributed_45_1/Relu_17       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [277] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_19 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [278] SensorFusionClassifier_1/time_distributed_45_1/Relu_18       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [279] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_2 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [280] SensorFusionClassifier_1/time_distributed_45_1/Relu_1        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [281] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_20 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [282] SensorFusionClassifier_1/time_distributed_45_1/Relu_19       shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [283] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_3 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [284] SensorFusionClassifier_1/time_distributed_45_1/Relu_2        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [285] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_4 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [286] SensorFusionClassifier_1/time_distributed_45_1/Relu_3        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [287] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_5 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [288] SensorFusionClassifier_1/time_distributed_45_1/Relu_4        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [289] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_6 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [290] SensorFusionClassifier_1/time_distributed_45_1/Relu_5        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [291] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_7 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [292] SensorFusionClassifier_1/time_distributed_45_1/Relu_6        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [293] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_8 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [294] SensorFusionClassifier_1/time_distributed_45_1/Relu_7        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [295] SensorFusionClassifier_1/time_distributed_45_1/strided_slice_9 shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [296] SensorFusionClassifier_1/time_distributed_45_1/Relu_8        shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [297] SensorFusionClassifier_1/time_distributed_45_1/stack         shape=[20  1 32 24  8], dtype=<class 'numpy.float32'>
#   [298] SensorFusionClassifier_1/td_pool1_1/strided_slice_1          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [299] SensorFusionClassifier_1/td_pool1_1/MaxPool2d                shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [300] SensorFusionClassifier_1/td_pool1_1/strided_slice_10         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [301] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_9              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [302] SensorFusionClassifier_1/td_pool1_1/strided_slice_11         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [303] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_10             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [304] SensorFusionClassifier_1/td_pool1_1/strided_slice_12         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [305] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_11             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [306] SensorFusionClassifier_1/td_pool1_1/strided_slice_13         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [307] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_12             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [308] SensorFusionClassifier_1/td_pool1_1/strided_slice_14         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [309] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_13             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [310] SensorFusionClassifier_1/td_pool1_1/strided_slice_15         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [311] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_14             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [312] SensorFusionClassifier_1/td_pool1_1/strided_slice_16         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [313] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_15             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [314] SensorFusionClassifier_1/td_pool1_1/strided_slice_17         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [315] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_16             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [316] SensorFusionClassifier_1/td_pool1_1/strided_slice_18         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [317] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_17             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [318] SensorFusionClassifier_1/td_pool1_1/strided_slice_19         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [319] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_18             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [320] SensorFusionClassifier_1/td_pool1_1/strided_slice_2          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [321] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_1              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [322] SensorFusionClassifier_1/td_pool1_1/strided_slice_20         shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [323] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_19             shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [324] SensorFusionClassifier_1/td_pool1_1/strided_slice_3          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [325] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_2              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [326] SensorFusionClassifier_1/td_pool1_1/strided_slice_4          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [327] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_3              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [328] SensorFusionClassifier_1/td_pool1_1/strided_slice_5          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [329] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_4              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [330] SensorFusionClassifier_1/td_pool1_1/strided_slice_6          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [331] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_5              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [332] SensorFusionClassifier_1/td_pool1_1/strided_slice_7          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [333] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_6              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [334] SensorFusionClassifier_1/td_pool1_1/strided_slice_8          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [335] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_7              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [336] SensorFusionClassifier_1/td_pool1_1/strided_slice_9          shape=[ 1 32 24  8], dtype=<class 'numpy.float32'>
#   [337] SensorFusionClassifier_1/td_pool1_1/MaxPool2d_8              shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [338] SensorFusionClassifier_1/td_pool1_1/stack                    shape=[20  1 16 12  8], dtype=<class 'numpy.float32'>
#   [339] SensorFusionClassifier_1/td_conv2_1/strided_slice_1          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [340] SensorFusionClassifier_1/td_conv2_1/BiasAdd;SensorFusionClassifier_1/td_conv2_1/convolution; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [341] SensorFusionClassifier_1/td_conv2_1/strided_slice_10         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [342] SensorFusionClassifier_1/td_conv2_1/BiasAdd_9;SensorFusionClassifier_1/td_conv2_1/convolution_9; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [343] SensorFusionClassifier_1/td_conv2_1/strided_slice_11         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [344] SensorFusionClassifier_1/td_conv2_1/BiasAdd_10;SensorFusionClassifier_1/td_conv2_1/convolution_10; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [345] SensorFusionClassifier_1/td_conv2_1/strided_slice_12         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [346] SensorFusionClassifier_1/td_conv2_1/BiasAdd_11;SensorFusionClassifier_1/td_conv2_1/convolution_11; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [347] SensorFusionClassifier_1/td_conv2_1/strided_slice_13         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [348] SensorFusionClassifier_1/td_conv2_1/BiasAdd_12;SensorFusionClassifier_1/td_conv2_1/convolution_12; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [349] SensorFusionClassifier_1/td_conv2_1/strided_slice_14         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [350] SensorFusionClassifier_1/td_conv2_1/BiasAdd_13;SensorFusionClassifier_1/td_conv2_1/convolution_13; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [351] SensorFusionClassifier_1/td_conv2_1/strided_slice_15         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [352] SensorFusionClassifier_1/td_conv2_1/BiasAdd_14;SensorFusionClassifier_1/td_conv2_1/convolution_14; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [353] SensorFusionClassifier_1/td_conv2_1/strided_slice_16         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [354] SensorFusionClassifier_1/td_conv2_1/BiasAdd_15;SensorFusionClassifier_1/td_conv2_1/convolution_15; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [355] SensorFusionClassifier_1/td_conv2_1/strided_slice_17         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [356] SensorFusionClassifier_1/td_conv2_1/BiasAdd_16;SensorFusionClassifier_1/td_conv2_1/convolution_16; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [357] SensorFusionClassifier_1/td_conv2_1/strided_slice_18         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [358] SensorFusionClassifier_1/td_conv2_1/BiasAdd_17;SensorFusionClassifier_1/td_conv2_1/convolution_17; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [359] SensorFusionClassifier_1/td_conv2_1/strided_slice_19         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [360] SensorFusionClassifier_1/td_conv2_1/BiasAdd_18;SensorFusionClassifier_1/td_conv2_1/convolution_18; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [361] SensorFusionClassifier_1/td_conv2_1/strided_slice_2          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [362] SensorFusionClassifier_1/td_conv2_1/BiasAdd_1;SensorFusionClassifier_1/td_conv2_1/convolution_1; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [363] SensorFusionClassifier_1/td_conv2_1/strided_slice_20         shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [364] SensorFusionClassifier_1/td_conv2_1/BiasAdd_19;SensorFusionClassifier_1/td_conv2_1/convolution_19; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [365] SensorFusionClassifier_1/td_conv2_1/strided_slice_3          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [366] SensorFusionClassifier_1/td_conv2_1/BiasAdd_2;SensorFusionClassifier_1/td_conv2_1/convolution_2; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [367] SensorFusionClassifier_1/td_conv2_1/strided_slice_4          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [368] SensorFusionClassifier_1/td_conv2_1/BiasAdd_3;SensorFusionClassifier_1/td_conv2_1/convolution_3; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [369] SensorFusionClassifier_1/td_conv2_1/strided_slice_5          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [370] SensorFusionClassifier_1/td_conv2_1/BiasAdd_4;SensorFusionClassifier_1/td_conv2_1/convolution_4; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [371] SensorFusionClassifier_1/td_conv2_1/strided_slice_6          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [372] SensorFusionClassifier_1/td_conv2_1/BiasAdd_5;SensorFusionClassifier_1/td_conv2_1/convolution_5; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [373] SensorFusionClassifier_1/td_conv2_1/strided_slice_7          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [374] SensorFusionClassifier_1/td_conv2_1/BiasAdd_6;SensorFusionClassifier_1/td_conv2_1/convolution_6; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [375] SensorFusionClassifier_1/td_conv2_1/strided_slice_8          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [376] SensorFusionClassifier_1/td_conv2_1/BiasAdd_7;SensorFusionClassifier_1/td_conv2_1/convolution_7; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [377] SensorFusionClassifier_1/td_conv2_1/strided_slice_9          shape=[ 1 16 12  8], dtype=<class 'numpy.float32'>
#   [378] SensorFusionClassifier_1/td_conv2_1/BiasAdd_8;SensorFusionClassifier_1/td_conv2_1/convolution_8; shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [379] SensorFusionClassifier_1/td_conv2_1/stack                    shape=[20  1 16 12 16], dtype=<class 'numpy.float32'>
#   [380] SensorFusionClassifier_1/time_distributed_46_1/strided_slice_1 shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [381] SensorFusionClassifier_1/time_distributed_46_1/strided_slice_10 shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [382] SensorFusionClassifier_1/time_distributed_46_1/strided_slice_11 shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [383] SensorFusionClassifier_1/time_distributed_46_1/strided_slice_12 shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [384] SensorFusionClassifier_1/time_distributed_46_1/strided_slice_13 shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
#   [385] SensorFusionClassifier_1/time_distributed_46_1/strided_slice_14 shape=[ 1 16 12 16], dtype=<class 'numpy.float32'>
# ...
#   [824] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_23/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [825] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_23/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [826] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_23/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [827] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_23/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [828] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_23/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [829] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_23/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [830] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/MatMul_1;SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/add shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [831] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/strided_slice shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [832] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/add_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [833] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/Sigmoid     shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [834] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/sub         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [835] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/mul_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [836] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/strided_slice_1 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [837] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/add_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [838] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/Sigmoid_1   shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [839] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [840] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [841] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [842] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [843] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [844] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_25/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [845] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/MatMul_1;SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/add shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [846] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/strided_slice shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [847] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/add_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [848] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/Sigmoid     shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [849] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/sub         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [850] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/mul_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [851] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/strided_slice_1 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [852] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/add_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [853] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/Sigmoid_1   shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [854] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [855] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [856] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [857] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [858] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [859] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_27/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [860] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/MatMul_1;SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/add shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [861] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/strided_slice shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [862] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/add_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [863] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/Sigmoid     shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [864] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/sub         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [865] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/mul_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [866] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/strided_slice_1 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [867] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/add_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [868] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/Sigmoid_1   shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [869] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [870] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [871] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [872] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [873] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [874] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_29/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [875] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/MatMul_1;SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/add shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [876] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/strided_slice shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [877] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/add_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [878] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/Sigmoid     shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [879] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/sub         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [880] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/mul_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [881] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/strided_slice_1 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [882] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/add_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [883] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/Sigmoid_1   shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [884] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [885] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [886] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [887] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [888] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [889] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_31/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [890] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/MatMul_1;SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/add shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [891] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/strided_slice shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [892] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/add_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [893] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/Sigmoid     shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [894] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/sub         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [895] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/mul_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [896] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/strided_slice_1 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [897] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/add_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [898] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/Sigmoid_1   shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [899] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [900] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [901] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [902] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [903] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [904] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_33/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [905] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/MatMul_1;SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/add shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [906] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/strided_slice shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [907] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/add_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [908] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/Sigmoid     shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [909] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/sub         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [910] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/mul_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [911] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/strided_slice_1 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [912] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/add_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [913] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/Sigmoid_1   shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [914] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [915] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [916] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [917] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [918] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [919] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_35/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [920] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/MatMul_1;SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/add shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [921] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/strided_slice shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [922] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/add_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [923] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/Sigmoid     shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [924] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/sub         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [925] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/mul_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [926] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/strided_slice_1 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [927] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/add_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [928] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/Sigmoid_1   shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [929] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [930] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [931] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [932] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [933] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [934] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_37/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [935] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/MatMul_1;SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/add shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [936] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/strided_slice shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [937] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/add_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [938] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/Sigmoid     shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [939] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/sub         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [940] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/mul_1       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [941] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/strided_slice_1 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [942] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/add_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [943] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/Sigmoid_1   shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [944] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/strided_slice_2 shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [945] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/mul         shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [946] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/add_3       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [947] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/Tanh        shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [948] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/mul_2       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [949] SensorFusionClassifier_1/ir_gru_1/ir_gru_cell_39/add_4       shape=[ 1 16], dtype=<class 'numpy.float32'>
#   [950] SensorFusionClassifier_1/fusion_1/concat                     shape=[ 1 48], dtype=<class 'numpy.float32'>
#   [951] SensorFusionClassifier_1/fc1_1/MatMul;SensorFusionClassifier_1/fc1_1/BiasAdd;SensorFusionClassifier_1/batch_normalization_56_1/batchnorm/mul_1;SensorFusionClassifier_1/re_lu_56_1/Relu;SensorFusionClassifier_1/batch_normalization_56_1/batchnorm/add_1 shape=[ 1 64], dtype=<class 'numpy.float32'>
#   [952] SensorFusionClassifier_1/output_1/MatMul;SensorFusionClassifier_1/output_1/BiasAdd shape=[1 3], dtype=<class 'numpy.float32'>
#   [953] StatefulPartitionedCall_1:0                                  shape=[1 3], dtype=<class 'numpy.float32'>
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
